# %% [markdown]
# ## Projeto - Análise de dados de ações

# %% [markdown]
# ### Leitura de dados com yfinance

# %% [markdown]
# https://pypi.org/project/yfinance/

# %%
import yfinance as yf

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
petr = yf.Ticker("PETR4.SA")

# %%
petr.history(period="max")
# Out:
#                  Open       High        Low      Close       Volume  \
# Date
# 2000-01-03   2.627551   2.627551   2.627551   2.627551  35389440000
# 2000-01-04   2.482197   2.482197   2.482197   2.482197  28861440000
# 2000-01-05   2.457152   2.457152   2.457152   2.457152  43033600000
# 2000-01-06   2.448654   2.448654   2.448654   2.448654  34055680000
# 2000-01-07   2.459836   2.459836   2.459836   2.459836  20912640000
# ...               ...        ...        ...        ...          ...
# 2022-08-03  34.009998  34.160000  33.560001  33.849998     65544500
# 2022-08-04  34.080002  34.400002  33.580002  34.209999     54387500
# 2022-08-05  34.150002  35.060001  34.119999  34.869999     77882600
# 2022-08-08  35.139999  36.770000  35.130001  36.630001    109484600
# 2022-08-09  37.009998  37.459999  36.849998  37.230000     79051200
#
#             Dividends  Stock Splits
# Date
# 2000-01-03        0.0           0.0
# 2000-01-04        0.0           0.0
# 2000-01-05        0.0           0.0
# 2000-01-06        0.0           0.0
# 2000-01-07        0.0           0.0
# ...               ...           ...
# 2022-08-03        0.0           0.0
# 2022-08-04        0.0           0.0
# 2022-08-05        0.0           0.0
# 2022-08-08        0.0           0.0
# 2022-08-09        0.0           0.0
#
# [5680 rows x 7 columns]

# %%
petr.history(period="max")["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
petr.info
# Out:
# {'zip': '20031-912',
#  'sector': 'Energy',
#  'fullTimeEmployees': 45532,
#  'longBusinessSummary': 'Petróleo Brasileiro S.A. - Petrobras explores for, produces, and sells oil and gas in Brazil and internationally. The company operates through Exploration and Production; Refining, Transportation and Marketing; Gas and Power; and Corporate and Other Businesses segments. It engages in prospecting, drilling, refining, processing, trading, and transporting crude oil from producing onshore and offshore oil fields, and shale or other rocks, as well as oil products, natural gas, and other liquid hydrocarbons. The Exploration and Production segment explores, develops, and produces crude oil, natural gas liquids, and natural gas primarily for supplies to the domestic refineries. The Refining, Transportation and Marketing segment engages in the refining, logistics, transport, marketing, and trading of crude oil and oil products; exportation of ethanol; and extraction and processing of shale, as well as holding interests in petrochemical companies. The Gas and Power segment is involved in the logistic and trading of natural gas and electricity; transportation and trading of LNG; generation of electricity through thermoelectric power plants; holding interests in transportation and distribution of natural gas; and fertilizer production and natural gas processing business. The Corporate and Other Businesses segment produces biodiesel and its co-products, and ethanol; and distributes oil products. Petróleo Brasileiro S.A. - Petrobras was incorporated in 1953 and is headquartered in Rio de Janeiro, Brazil.',
#  'city': 'Rio De Janeiro',
#  'phone': '55 21 3224 4477',
#  'state': 'RJ',
#  'country': 'Brazil',
#  'companyOfficers': [],
#  'website': 'https://petrobras.com.br',
#  'maxAge': 1,
#  'address1': 'Avenida RepUblica do Chile, 65',
#  'industry': 'Oil & Gas Integrated',
#  'address2': 'Centro',
#  'ebitdaMargins': 0.52679,
#  'profitMargins': 0.2842,
#  'grossMargins': 0.50886,
#  'operatingCashflow': 231119994880,
#  'revenueGrowth': 0.544,
#  'operatingMargins': 0.46785,
#  'ebitda': 299421007872,
#  'targetLowPrice': 13,
#  'recommendationKey': 'buy',
#  'grossProfits': 219637000000,
#  'freeCashflow': 200201879552,
#  'targetMedianPrice': 42.5,
#  'currentPrice': 37.11,
#  'earningsGrowth': 0.268,
#  'currentRatio': 1.313,
#  'returnOnAssets': 0.17079,
#  'numberOfAnalystOpinions': 8,
#  'targetMeanPrice': 39.06,
#  'debtToEquity': 67.975,
#  'returnOnEquity': 0.41849,
#  'targetHighPrice': 53,
#  'totalCash': 100267999232,
#  'totalDebt': 280637014016,
#  'totalRevenue': 568385011712,
#  'totalCashPerShare': 7.687,
#  'financialCurrency': 'BRL',
#  'revenuePerShare': 43.574,
#  'quickRatio': 0.779,
#  'recommendationMean': 2.2,
#  'exchange': 'SAO',
#  'shortName': 'PETROBRAS   PN      N2',
#  'longName': 'Petróleo Brasileiro S.A. - Petrobras',
#  'exchangeTimezoneName': 'America/Sao_Paulo',
#  'exchangeTimezoneShortName': 'BRT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-10800000',
#  'quoteType': 'EQUITY',
#  'symbol': 'PETR4.SA',
#  'messageBoardId': 'finmb_409268',
#  'market': 'br_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 1.176,
#  'beta3Year': None,
#  'enterpriseToEbitda': 2.232,
#  '52WeekChange': 0.29856992,
#  'morningStarRiskRating': None,
#  'forwardEps': 10.74,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 5601970176,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 31.473,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.43890998,
#  'netIncomeToCommon': 161536999424,
#  'trailingEps': 12.17,
#  'lastDividendValue': 6.732003,
#  'SandP52WeekChange': -0.07201946,
#  'priceToBook': 1.1791059,
#  'heldPercentInsiders': 0.16069001,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1656547200,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 8268327853,
#  'beta': 1.36282,
#  'enterpriseValue': 668311617536,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1209340800,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1660262400,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.268,
#  'priceToSalesTrailing12Months': 0.88585156,
#  'dateShortInterest': None,
#  'pegRatio': None,
#  'ytdReturn': None,
#  'forwardPE': 3.4553075,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 37.23,
#  'regularMarketOpen': 37.65,
#  'twoHundredDayAverage': 30.7054,
#  'trailingAnnualDividendYield': 0.16416869,
#  'payoutRatio': 0.955,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 37.65,
#  'navPrice': None,
#  'averageDailyVolume10Day': 88943690,
#  'regularMarketPreviousClose': 37.23,
#  'fiftyDayAverage': 29.8542,
#  'trailingAnnualDividendRate': 6.112,
#  'open': 37.65,
#  'toCurrency': None,
#  'averageVolume10days': 88943690,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 10.45,
#  'exDividendDate': 1660262400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 36.61,
#  'currency': 'BRL',
#  'trailingPE': 3.0493016,
#  'regularMarketVolume': 77379500,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 503504764928,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 73254743,
#  'dayLow': 36.61,
#  'ask': 37.07,
#  'askSize': 0,
#  'volume': 77379500,
#  'fiftyTwoWeekHigh': 37.65,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 23.79,
#  'bid': 37.1,
#  'tradeable': False,
#  'dividendYield': 0.28059998,
#  'bidSize': 0,
#  'dayHigh': 37.65,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 37.11,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/petrobras.com.br',
#  'trailingPegRatio': 0.6306}

# %%
petr.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2005-04-01   0.133288           0.0
# 2005-07-01   0.250663           0.0
# 2005-09-01   0.000000           4.0
# 2006-01-02   0.259000           0.0
# 2006-04-04   0.132700           0.0
# 2006-11-01   0.500750           0.0
# 2007-01-02   0.225000           0.0
# 2007-04-03   0.175000           0.0
# 2007-08-20   0.251700           0.0
# 2007-10-08   0.256500           0.0
# 2008-01-14   0.155300           0.0
# 2008-04-07   0.102600           0.0
# 2008-04-28   0.000000           2.0
# 2008-12-29   0.042600           0.0
# 2009-04-09   0.351600           0.0
# 2009-07-06   0.300000           0.0
# 2009-10-01   0.200000           0.0
# 2009-12-21   0.200000           0.0
# 2010-04-23   0.133200           0.0
# 2010-05-24   0.170000           0.0
# 2010-08-02   0.170000           0.0
# 2010-11-03   0.140000           0.0
# 2010-12-22   0.200000           0.0
# 2011-03-22   0.173420           0.0
# 2011-04-29   0.126500           0.0
# 2011-05-12   0.213600           0.0
# 2011-08-03   0.207300           0.0
# 2011-11-14   0.200000           0.0
# 2012-01-03   0.177300           0.0
# 2012-03-20   0.124400           0.0
# 2012-05-14   0.200000           0.0
# 2013-04-30   0.386170           0.0
# 2014-04-03   0.967200           0.0
# 2018-05-22   0.050000           0.0
# 2018-08-14   0.050000           0.0
# 2018-11-22   0.100000           0.0
# 2018-12-26   0.716563           0.0
# 2019-04-26   0.019494           0.0
# 2019-05-22   0.100000           0.0
# 2019-08-13   0.200000           0.0
# 2019-11-12   0.200925           0.0
# 2019-12-27   0.421942           0.0
# 2020-04-23   0.000449           0.0
# 2020-04-28   0.000449           0.0
# 2020-07-23   0.000461           0.0
# 2021-04-15   0.792834           0.0
# 2021-08-17   1.609911           0.0
# 2021-12-02   3.250487           0.0
# 2022-04-14   2.970249           0.0
# 2022-05-24   3.715490           0.0

# %%
petr.financials
petr.quarterly_financials
# Out:
#                                             2022-06-30      2022-03-31  \
# Research Development                      1080000000.0    1081000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        80677000000.0   68381000000.0
# Minority Interest                         2307000000.0    2867000000.0
# Net Income                               54330000000.0   44561000000.0
# Selling General Administrative            7725000000.0    7718000000.0
# Gross Profit                             95861000000.0   74766000000.0
# Ebit                                     98817000000.0   61213000000.0
# Operating Income                         98817000000.0   61213000000.0
# Other Operating Expenses                -11957000000.0    4346000000.0
# Interest Expense                         -3576000000.0   -3066000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                       26193000000.0   23598000000.0
# Total Revenue                           170960000000.0  141641000000.0
# Total Operating Expenses                 72143000000.0   80428000000.0
# Cost Of Revenue                          75099000000.0   66875000000.0
# Total Other Income Expense Net          -18140000000.0    7168000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           54484000000.0   44783000000.0
# Net Income Applicable To Common Shares   54330000000.0   44561000000.0
#
#                                             2021-12-31      2021-09-30
# Research Development                       827000000.0     792000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        44485000000.0   40977000000.0
# Minority Interest                         2252000000.0    6612000000.0
# Net Income                               31504000000.0   31142000000.0
# Selling General Administrative            7810000000.0    7529000000.0
# Gross Profit                             59047000000.0   59552000000.0
# Ebit                                     49577000000.0   48857000000.0
# Operating Income                         49577000000.0   48857000000.0
# Other Operating Expenses                   431000000.0    1678000000.0
# Interest Expense                         -8356000000.0   -2093000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                       12762000000.0    9753000000.0
# Total Revenue                           176587000000.0  106020000000.0
# Total Operating Expenses                127010000000.0   57163000000.0
# Cost Of Revenue                         117540000000.0   46468000000.0
# Total Other Income Expense Net           -5092000000.0   -7880000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           31723000000.0   31224000000.0
# Net Income Applicable To Common Shares   31504000000.0   31142000000.0

# %%
# show major holders
petr.major_holders

# show institutional holders
petr.institutional_holders

# show balance sheet
petr.balance_sheet
petr.quarterly_balance_sheet

# show cashflow
petr.cashflow
petr.quarterly_cashflow

# show earnings
petr.earnings
petr.quarterly_earnings

# %%
tickers = yf.Tickers('PETR4.SA ABEV3.SA AMER3.SA')

# %%
tickers.tickers
# Out:
# {'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'AMER3.SA': yfinance.Ticker object <AMER3.SA>}

# %%
tickers.tickers["PETR4.SA"].balance_sheet

# %% [markdown]
# ## Ibovespa
# https://www.b3.com.br/pt_br/market-data-e-indices/indices/indices-amplos/indice-ibovespa-ibovespa-composicao-da-carteira.htm

# %%
df_ibov = pd.read_csv("IBOVDia_09-08-22.csv")
df_ibov
# Out:
#    Código          Ação        Tipo  Qtde. Teórica Part. (%)
# 0   RRRP3  3R PETROLEUM  ON      NM    200.372.163     0,341
# 1   ALPA4    ALPARGATAS  PN      N1    201.257.220     0,193
# 2   ABEV3     AMBEV S/A          ON  4.380.195.841     3,214
# 3   AMER3    AMERICANAS  ON      NM    596.875.824     0,421
# 4   ASAI3         ASSAI  ON      NM    794.531.367     0,682
# ..    ...           ...         ...            ...       ...
# 85  VALE3          VALE  ON      NM  3.768.748.489    12,817
# 86  VIIA3           VIA  ON      NM  1.596.295.753     0,231
# 87  VBBR3         VIBRA  ON      NM  1.131.883.365     1,016
# 88  WEGE3           WEG  ON      NM  1.484.859.030     2,189
# 89  YDUQ3    YDUQS PART  ON      NM    300.833.122     0,231
#
# [90 rows x 5 columns]

# %%
df_ibov["Part. (%)"] = df_ibov["Part. (%)"].apply(lambda x: float(x.replace(",", ".")))

# %% [markdown]
# #### 1. Vamos analisar o histórico das 10 ações com maior participacão na bolsa. Encontre estes ativos no DataFrame `df_ibov` e carregue-os em um objeto Tickers do módulo do Yahoo.

# %%
acoes = df_ibov.sort_values("Part. (%)").tail(10)["Código"].values

# %%
my_list = ["how", "are", "you"]
" ".join(my_list)
# Out:
# 'how are you'

# %%
" ".join(acoes)
# Out:
# ['RENT3.SA',
#  'ELET3.SA',
#  'BBAS3.SA',
#  'ABEV3.SA',
#  'B3SA3.SA',
#  'BBDC4.SA',
#  'PETR3.SA',
#  'ITUB4.SA',
#  'PETR4.SA',
#  'VALE3.SA']

# %%
tickers = yf.Tickers(" ".join([i + '.SA' for i in acoes]))
tickers.tickers
# Out:
# {'RENT3.SA': yfinance.Ticker object <RENT3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'PETR3.SA': yfinance.Ticker object <PETR3.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'VALE3.SA': yfinance.Ticker object <VALE3.SA>}

# %% [markdown]
# #### 2. Crie um dicionário que conterá como chaves os tickers de cada ativo (PETR4.SA, por exemplo) e como valores um DataFrame contendo os dados históricos de cada

# %%
tickers.tickers
# Out:
# {'RENT3.SA': yfinance.Ticker object <RENT3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'PETR3.SA': yfinance.Ticker object <PETR3.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'VALE3.SA': yfinance.Ticker object <VALE3.SA>}

# %%
dict_data = {}

for ticker in tickers.tickers.keys():
    print("Baixando: {}".format(ticker))
    dict_data[ticker] = tickers.tickers[ticker].history(period="max")
# Out:
# Baixando: RENT3.SA
# Baixando: ELET3.SA
# Baixando: BBAS3.SA
# Baixando: ABEV3.SA
# Baixando: B3SA3.SA
# Baixando: BBDC4.SA
# Baixando: PETR3.SA
# Baixando: ITUB4.SA
# Baixando: PETR4.SA
# Baixando: VALE3.SA

# %%
dict_data["ITUB4.SA"]
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2000-12-21   1.739687   1.846602   1.739483   1.829311      74224        0.0
# 2000-12-22   1.810896   1.810896   1.739279   1.750022      23312        0.0
# 2000-12-25   1.750022   1.750022   1.750022   1.750022          0        0.0
# 2000-12-26   1.740404   1.751556   1.723932   1.749510       7851        0.0
# 2000-12-27   1.780203   1.808851   1.749510   1.808851      26996        0.0
# ...               ...        ...        ...        ...        ...        ...
# 2022-08-03  23.700001  23.940001  23.540001  23.889999   20046500        0.0
# 2022-08-04  24.049999  24.570000  23.969999  24.469999   33908800        0.0
# 2022-08-05  24.490000  25.129999  24.230000  24.930000   56500800        0.0
# 2022-08-08  25.080000  25.290001  24.780001  25.240000   40938100        0.0
# 2022-08-09  26.040001  26.280001  25.290001  25.900000  103830600        0.0
#
#             Stock Splits
# Date
# 2000-12-21           0.0
# 2000-12-22           0.0
# 2000-12-25           0.0
# 2000-12-26           0.0
# 2000-12-27           0.0
# ...                  ...
# 2022-08-03           0.0
# 2022-08-04           0.0
# 2022-08-05           0.0
# 2022-08-08           0.0
# 2022-08-09           0.0
#
# [5427 rows x 7 columns]

# %% [markdown]
# #### 3. Combine todos os dados em um único DataFrame, utilizando o preço de fechamento de cada ativo.

# %%
ticker
# Out:
# 'ELET3.SA'

# %%
dict_data[ticker]["Close"]
# Out:
# Date
# 2000-01-03     8.445017
# 2000-01-04     8.036734
# 2000-01-05     8.359063
# 2000-01-06     8.165666
# 2000-01-07     8.294597
#                 ...
# 2022-08-03    47.009998
# 2022-08-04    48.320000
# 2022-08-05    48.130001
# 2022-08-08    48.290001
# 2022-08-09    48.330002
# Name: Close, Length: 5680, dtype: float64

# %%
df_data = pd.DataFrame()

for ticker in dict_data.keys():
    df_aux = dict_data[ticker].rename(columns={"Close": ticker})
    df_data = df_data.join(df_aux[ticker], how="outer")

# %%
df_data
# Out:
#              RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA  B3SA3.SA   BBDC4.SA  \
# Date
# 2000-01-03        NaN   8.445017   1.182134        NaN       NaN        NaN
# 2000-01-04        NaN   8.036734   1.125910        NaN       NaN        NaN
# 2000-01-05        NaN   8.359063   1.137443   0.321626       NaN        NaN
# 2000-01-06        NaN   8.165666   1.153301   0.305322       NaN        NaN
# 2000-01-07        NaN   8.294597   1.127352   0.305322       NaN        NaN
# ...               ...        ...        ...        ...       ...        ...
# 2022-08-03  59.220001  47.009998  36.410000  14.630000     11.16  17.950001
# 2022-08-04  62.139999  48.320000  37.099998  14.680000     11.90  18.280001
# 2022-08-05  62.150002  48.130001  37.790001  14.600000     12.07  18.500000
# 2022-08-08  63.400002  48.290001  38.980000  14.800000     12.45  18.559999
# 2022-08-09  61.799999  48.330002  39.630001  14.740000     12.25  18.830000
#
#              PETR3.SA   ITUB4.SA   PETR4.SA   VALE3.SA
# Date
# 2000-01-03   2.512534        NaN   2.627550   1.795995
# 2000-01-04   2.371526        NaN   2.482198   1.753232
# 2000-01-05   2.403573        NaN   2.457152   1.753232
# 2000-01-06   2.384345        NaN   2.448655   1.753232
# 2000-01-07   2.403573        NaN   2.459835   1.817376
# ...               ...        ...        ...        ...
# 2022-08-03  36.320000  23.889999  33.849998  67.519997
# 2022-08-04  36.880001  24.469999  34.209999  67.129997
# 2022-08-05  37.520000  24.930000  34.869999  68.000000
# 2022-08-08  39.330002  25.240000  36.630001  68.580002
# 2022-08-09  39.849998  25.900000  37.230000  70.000000
#
# [5682 rows x 10 columns]

# %% [markdown]
# #### 4. Qual a primeira data na qual todos os ativos estudados já estavam na bolsa?

# %%
df_data.dropna().index[0]
# Out:
# Timestamp('2008-01-02 00:00:00')

# %% [markdown]
# #### 5. Crie um DataFrame adicional para representar a variação percentual diária de cada ativo

# %%
df_ret = df_data / df_data.shift(1) - 1

# %% [markdown]
# #### 6. Quais foram as datas na qual cada ativo apresentou sua pior oscilação? Apresente também a variação percentual.

# %%
df_ret.idxmin()
# Out:
# RENT3.SA   2020-03-16
# ELET3.SA   2010-02-01
# BBAS3.SA   2016-03-15
# ABEV3.SA   2005-04-04
# B3SA3.SA   2011-05-09
# BBDC4.SA   2009-05-29
# PETR3.SA   2020-03-09
# ITUB4.SA   2021-10-04
# PETR4.SA   2020-03-09
# VALE3.SA   2019-01-28
# dtype: datetime64[ns]

# %%
df_ret.min()
# Out:
# RENT3.SA   -0.234218
# ELET3.SA   -0.220074
# BBAS3.SA   -0.211712
# ABEV3.SA   -0.224262
# B3SA3.SA   -0.661336
# BBDC4.SA   -0.432507
# PETR3.SA   -0.296758
# ITUB4.SA   -0.179643
# PETR4.SA   -0.296978
# VALE3.SA   -0.245592
# dtype: float64

# %% [markdown]
# #### 7. Analisando esta série temporal, você conseguira estimar se existe uma maior probabilidade dos ativos performarem bem logo após um dia de queda?

# %%
df_ret
# Out:
#             RENT3.SA  ELET3.SA  BBAS3.SA  ABEV3.SA  B3SA3.SA  BBDC4.SA  \
# Date
# 2000-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-04       NaN -0.048346 -0.047562       NaN       NaN       NaN
# 2000-01-05       NaN  0.040107  0.010243       NaN       NaN       NaN
# 2000-01-06       NaN -0.023136  0.013942 -0.050691       NaN       NaN
# 2000-01-07       NaN  0.015789 -0.022500  0.000000       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-03  0.031168  0.003201  0.006914 -0.005438  0.033333  0.015846
# 2022-08-04  0.049308  0.027866  0.018951  0.003418  0.066308  0.018384
# 2022-08-05  0.000161 -0.003932  0.018598 -0.005450  0.014286  0.012035
# 2022-08-08  0.020113  0.003324  0.031490  0.013699  0.031483  0.003243
# 2022-08-09 -0.025237  0.000828  0.016675 -0.004054 -0.016064  0.014547
#
#             PETR3.SA  ITUB4.SA  PETR4.SA  VALE3.SA
# Date
# 2000-01-03       NaN       NaN       NaN       NaN
# 2000-01-04 -0.056122       NaN -0.055318 -0.023810
# 2000-01-05  0.013513       NaN -0.010090  0.000000
# 2000-01-06 -0.008000       NaN -0.003458  0.000000
# 2000-01-07  0.008064       NaN  0.004566  0.036586
# ...              ...       ...       ...       ...
# 2022-08-03 -0.005476  0.007167  0.000591 -0.038861
# 2022-08-04  0.015419  0.024278  0.010635 -0.005776
# 2022-08-05  0.017354  0.018799  0.019293  0.012960
# 2022-08-08  0.048241  0.012435  0.050473  0.008529
# 2022-08-09  0.013221  0.026149  0.016380  0.020706
#
# [5682 rows x 10 columns]

# %%
df_ret[df_ret.shift(1) < 0].mean()
# Out:
# RENT3.SA    0.001441
# ELET3.SA    0.000007
# BBAS3.SA    0.000426
# ABEV3.SA    0.001093
# B3SA3.SA    0.001291
# BBDC4.SA    0.001053
# PETR3.SA    0.000330
# ITUB4.SA    0.000455
# PETR4.SA    0.000548
# VALE3.SA    0.000432
# dtype: float64

# %%
df_ret[df_ret.shift(1) < 0].std()
# Out:
# RENT3.SA    0.027931
# ELET3.SA    0.031628
# BBAS3.SA    0.028698
# ABEV3.SA    0.018822
# B3SA3.SA    0.029035
# BBDC4.SA    0.024846
# PETR3.SA    0.029618
# ITUB4.SA    0.023446
# PETR4.SA    0.028848
# VALE3.SA    0.026062
# dtype: float64

# %%
df_study = df_ret[df_ret.shift(1) < 0]

fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(df_study, kde=True)

print("Média dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].mean()*100))
    
print("Desvio padrão dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].std()*100))
# Out:
# Média dos retornos
# RENT3 - 0.144136080922173
# ELET3 - 0.0006558680947882445
# BBAS3 - 0.04255311829321438
# ABEV3 - 0.10929088649253374
# B3SA3 - 0.12909551479374098
# BBDC4 - 0.10528202665108854
# PETR3 - 0.0329615513897106
# ITUB4 - 0.04552433246481971
# PETR4 - 0.054777868196333894
# VALE3 - 0.043225248259492206
# Desvio padrão dos retornos
# RENT3 - 2.7930633587041327
# ELET3 - 3.162812131655969
# BBAS3 - 2.8698415284142555
# ABEV3 - 1.8822113713987603
# B3SA3 - 2.9034784761008634
# BBDC4 - 2.484598478635562
# PETR3 - 2.9618219675172726
# ITUB4 - 2.3445509314224404
# PETR4 - 2.884804364813116
# VALE3 - 2.606183161907867

# %% [markdown]
# #### 8. Seguindo a lógica da questão anterior, avalie como em média se comportam as ações no pregão seguinte a quedas maiores que 1%. De posse destes dados, você acredita que seria uma boa estratégia de investimento comprar ações que cairam no dia anterior?

# %%
df_study = df_ret[df_ret.shift(1) < -0.05]

fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(df_study, kde=True)

print("Média dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].mean()*100))
    
print("Desvio padrão dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].std()*100))
# Out:
# Média dos retornos
# RENT3 - 0.3711607288507846
# ELET3 - 0.132842986115102
# BBAS3 - 0.5488666075833527
# ABEV3 - 1.2388310175275956
# B3SA3 - 0.12223405703762848
# BBDC4 - 1.3695123934421713
# PETR3 - 0.17346661753510867
# ITUB4 - 0.5178220054199956
# PETR4 - 0.16092321771689755
# VALE3 - 0.19816979630810902
# Desvio padrão dos retornos
# RENT3 - 6.42894438466914
# ELET3 - 4.97571045426172
# BBAS3 - 4.69974728434283
# ABEV3 - 4.309392664606994
# B3SA3 - 6.337027101545176
# BBDC4 - 6.225082253912538
# PETR3 - 5.64950529957998
# ITUB4 - 4.89457011635996
# PETR4 - 6.0867477610669996
# VALE3 - 4.8736179841134115

# %% [markdown]
# ### DESAFIOS

# %% [markdown]
# #### 9. De tempos em tempos, empresas podem distribuir lucro aos acionistas na forma de dividendos. Podemos obter o histórico de pagamentos de dividendos usando a yfinance. Um indicador muito utilizado no mercado é o Dividend Yield (DY), que é calculado somando-se o total pago de dividendos no ano e dividindo pela cotação da ação. Calcule o DY anual de cada ativo.

# %%
df_data
# Out:
#              RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA  B3SA3.SA   BBDC4.SA  \
# Date
# 2000-01-03        NaN   8.445017   1.182134        NaN       NaN        NaN
# 2000-01-04        NaN   8.036734   1.125910        NaN       NaN        NaN
# 2000-01-05        NaN   8.359063   1.137443   0.321626       NaN        NaN
# 2000-01-06        NaN   8.165666   1.153301   0.305322       NaN        NaN
# 2000-01-07        NaN   8.294597   1.127352   0.305322       NaN        NaN
# ...               ...        ...        ...        ...       ...        ...
# 2022-08-03  59.220001  47.009998  36.410000  14.630000     11.16  17.950001
# 2022-08-04  62.139999  48.320000  37.099998  14.680000     11.90  18.280001
# 2022-08-05  62.150002  48.130001  37.790001  14.600000     12.07  18.500000
# 2022-08-08  63.400002  48.290001  38.980000  14.800000     12.45  18.559999
# 2022-08-09  61.799999  48.330002  39.630001  14.740000     12.25  18.830000
#
#              PETR3.SA   ITUB4.SA   PETR4.SA   VALE3.SA
# Date
# 2000-01-03   2.512534        NaN   2.627550   1.795995
# 2000-01-04   2.371526        NaN   2.482198   1.753232
# 2000-01-05   2.403573        NaN   2.457152   1.753232
# 2000-01-06   2.384345        NaN   2.448655   1.753232
# 2000-01-07   2.403573        NaN   2.459835   1.817376
# ...               ...        ...        ...        ...
# 2022-08-03  36.320000  23.889999  33.849998  67.519997
# 2022-08-04  36.880001  24.469999  34.209999  67.129997
# 2022-08-05  37.520000  24.930000  34.869999  68.000000
# 2022-08-08  39.330002  25.240000  36.630001  68.580002
# 2022-08-09  39.849998  25.900000  37.230000  70.000000
#
# [5682 rows x 10 columns]

# %%
tickers.tickers['RENT3.SA'].dividends
# Out:
# Date
# 2007-12-20    0.010644
# 2008-03-28    0.010574
# 2008-04-09    0.035259
# 2008-04-11    0.035566
# 2008-07-03    0.010371
#                 ...
# 2021-09-30    0.109203
# 2021-12-20    0.129163
# 2022-03-30    0.146695
# 2022-05-02    0.274131
# 2022-07-01    0.174938
# Name: Dividends, Length: 72, dtype: float64

# %%
df_dividends = pd.DataFrame()

for ticker in tickers.tickers.keys():
    df_dividends_aux = tickers.tickers[ticker].dividends.to_frame().rename(columns={"Dividends": ticker})
    df_dividends = df_dividends.join(df_dividends_aux, how='outer')

# %%
df_dividends['year'] = df_dividends.index.year
df_data["year"] = df_data.index.year

# %%
df_dividends_year = df_dividends.groupby("year").sum()
df_last_price = df_data.dropna().groupby("year").last()

# %%
df_yield = df_dividends_year/df_last_price  * 100
df_yield.dropna(inplace=True)

# %%
df_yield
# Out:
#        RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA  B3SA3.SA  BBDC4.SA  \
# year
# 2008   8.028907   3.676718   0.000000   4.519912  0.657630  4.963694
# 2009   1.157707   9.205332   6.709814   4.147106  1.446878  3.590367
# 2010   0.828587  31.806510  11.964925   2.016075  1.896350  3.931120
# 2011   1.868180   9.260188  15.367178   2.893163  8.156045  5.465314
# 2012   1.542420  34.954400  11.627108   3.988183  4.262620  4.284106
# 2013  18.514381  32.140855  16.128331   2.048201  9.389476  4.362870
# 2014   1.515416   8.929437  10.811475   4.848154  5.512071  5.253746
# 2015   2.943410   0.000000  19.599311  10.712200  9.201936  9.608523
# 2016   2.779438   0.000000   4.356004   4.556661  3.710761  5.798698
# 2017   1.174669   0.000000   3.859499   2.881793  2.366803  4.487350
# 2018   0.942518   0.000000   4.059017   3.932702  3.025916  3.500011
# 2019   0.855431   2.778034   6.954399   2.815844  2.118233  8.301173
# 2020   0.513368   9.614498   4.274500   2.759705  2.854507  2.726741
# 2021   0.845905   7.312751   8.187875   4.411803  9.031406  5.509954
# 2022   0.964019   1.526253   3.636086   0.000000  2.955331  1.914291
#
#        PETR3.SA  ITUB4.SA   PETR4.SA   VALE3.SA
# year
# 2008   0.282879  0.000000   2.616111   3.996367
# 2009   4.495432  0.000000   5.515414   3.839789
# 2010   4.434560  1.232735   5.568367   2.981321
# 2011   6.618707  7.959288   7.709280  11.073036
# 2012   4.202124  5.079292   4.516342   8.848150
# 2013   1.365766  4.456540   3.897818   4.427156
# 2014   8.798476  3.888458  15.591044  12.981016
# 2015   0.000000  7.455411   0.000000  10.689592
# 2016   0.000000  5.843568   0.000000   0.919334
# 2017   0.000000  4.204686   0.000000   4.475336
# 2018   1.535713  6.243167   6.263415   5.043425
# 2019   2.390532  5.236317   4.683805   3.377176
# 2020   3.604236  2.572151   0.007193   3.363123
# 2021  22.098699  4.358512  24.224929  19.512221
# 2022  16.777263  0.666062  17.957935   5.313223

# %% [markdown]
# #### 10. Avalie o desempenho de uma estratégia de investimento que monta uma carteira de ações ano a ano com as 3 maiores pagadoras de dividendo do ano anterior. Compare o desempenho dela com o desempenho de uma carteira global.

# %%
df_ret_year = df_last_price / df_last_price.shift(1) - 1

# %%
((df_ret_year / 10).sum(axis=1) + 1).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_yield.iloc[0, :].nlargest(3).index
# Out:
# Index(['RENT3.SA', 'BBDC4.SA', 'ABEV3.SA'], dtype='object')

# %%
df_yield
# Out:
#        RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA  B3SA3.SA  BBDC4.SA  \
# year
# 2008   8.028907   3.676718   0.000000   4.519912  0.657630  4.963694
# 2009   1.157707   9.205332   6.709814   4.147106  1.446878  3.590367
# 2010   0.828587  31.806510  11.964925   2.016075  1.896350  3.931120
# 2011   1.868180   9.260188  15.367178   2.893163  8.156045  5.465314
# 2012   1.542420  34.954400  11.627108   3.988183  4.262620  4.284106
# 2013  18.514381  32.140855  16.128331   2.048201  9.389476  4.362870
# 2014   1.515416   8.929437  10.811475   4.848154  5.512071  5.253746
# 2015   2.943410   0.000000  19.599311  10.712200  9.201936  9.608523
# 2016   2.779438   0.000000   4.356004   4.556661  3.710761  5.798698
# 2017   1.174669   0.000000   3.859499   2.881793  2.366803  4.487350
# 2018   0.942518   0.000000   4.059017   3.932702  3.025916  3.500011
# 2019   0.855431   2.778034   6.954399   2.815844  2.118233  8.301173
# 2020   0.513368   9.614498   4.274500   2.759705  2.854507  2.726741
# 2021   0.845905   7.312751   8.187875   4.411803  9.031406  5.509954
# 2022   0.964019   1.526253   3.636086   0.000000  2.955331  1.914291
#
#        PETR3.SA  ITUB4.SA   PETR4.SA   VALE3.SA
# year
# 2008   0.282879  0.000000   2.616111   3.996367
# 2009   4.495432  0.000000   5.515414   3.839789
# 2010   4.434560  1.232735   5.568367   2.981321
# 2011   6.618707  7.959288   7.709280  11.073036
# 2012   4.202124  5.079292   4.516342   8.848150
# 2013   1.365766  4.456540   3.897818   4.427156
# 2014   8.798476  3.888458  15.591044  12.981016
# 2015   0.000000  7.455411   0.000000  10.689592
# 2016   0.000000  5.843568   0.000000   0.919334
# 2017   0.000000  4.204686   0.000000   4.475336
# 2018   1.535713  6.243167   6.263415   5.043425
# 2019   2.390532  5.236317   4.683805   3.377176
# 2020   3.604236  2.572151   0.007193   3.363123
# 2021  22.098699  4.358512  24.224929  19.512221
# 2022  16.777263  0.666062  17.957935   5.313223

# %%
strategy_return = []

for i in range(len(df_yield) - 1):
    stocks = df_yield.iloc[i, :].nlargest(3).index 
    strategy_return += [(df_ret_year[stocks].iloc[i + 1] / 3).sum() + 1]

# %%
df_global = df_ret_year / 10

fig, ax = plt.subplots()
pd.DataFrame(strategy_return, index=df_global.index[1:]).cumprod().plot(color="red", ax=ax)
(df_global.sum(axis=1) + 1).cumprod().plot(color="blue", ax=ax)
# Out:
# <AxesSubplot:xlabel='year'>
